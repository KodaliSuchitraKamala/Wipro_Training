# %% [markdown]
# <a href="https://colab.research.google.com/github/KodaliSuchitraKamala/Wipro_Training/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification types
#  1. Logistic Regression
#  2. KNN

# %% [markdown]
# ### Logistic Regression

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
x = np.array([[25, 30000], [30, 50000], [35, 60000], [40, 80000], [ 45, 20000], [28, 40000]])
y = ([0, 1, 1, 1, 0, 0])
scaler = StandardScaler()
x_scale = scaler.fit_transform(x)
model = LogisticRegression()
model.fit(x_scale, y)
y_pred = model.predict(x_scale)
accuracy = accuracy_score(y, y_pred)
print("Accuracy: ", accuracy)
print("Coefficient (age / income): ", model.coef_)
print("Intercept: ", model.intercept_[0])
new_c = np.array([[32, 55000]])
new_c_s = scaler.transform(new_c)
prediction = model.predict(new_c_s)
probability = model.predict_proba(new_c_s)
print("Predicted Class (0 -> no / 1 -> yes): ", prediction[0])
print("Probabilities (no / yes): ", probability[0])
# Out:
# Accuracy:  1.0
# Coefficient (age / income):  [[0.16354718 1.12196628]]
# Intercept:  0.05880264020465901
# Predicted Class (0 -> no / 1 -> yes):  1
# Probabilities (no / yes):  [0.37992806 0.62007194]

# %% [markdown]
# ### Seaborn
#  1. Themes built-in - predefined styles
#  2. Stastical plots
#  3. integrate pandas
#  4. colors palettes
#
# set_style("") whitegrid, darkgrid, ticks, white, dark

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
data = {'hours': [2, 4, 6, 8, 10, 3, 5, 7, 9, 1],
        'score': [50, 60, 70, 80, 90, 55, 65, 75, 85, 45],
        'pass': [0, 0, 1, 1, 1, 0, 1, 1, 1, 0]}
df = pd.DataFrame(data)
plt.figure(figsize = (8, 4))
sns.scatterplot(x = 'hours', y = 'score', hue = 'pass', style = 'pass', data = df, palette = 'coolwarm')
plt.suptitle("Pairplot for Pass / Fail")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
data = {'hours': [2, 4, 6, 8, 10, 3, 5, 7, 9, 1],
        'score': [50, 60, 70, 80, 90, 55, 65, 75, 85, 45],
        'pass': [0, 0, 1, 1, 1, 0, 1, 1, 1, 0]}
df = pd.DataFrame(data)
plt.figure(figsize = (8, 4))
sns.scatterplot(x = 'hours', y = 'score', hue = 'pass', style = 'pass', data = df, palette = 'coolwarm')
plt.suptitle("Pairplot for Pass / Fail")
plt.show()
sns.pairplot(df, hue = 'pass', palette = 'coolwarm', diag_kind = 'hist')
plt.suptitle("PairPlot for Pass / Fail")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
data = {'hours': [2, 4, 6, 8, 10, 3, 5, 7, 9, 1],
        'score': [50, 60, 70, 80, 90, 55, 65, 75, 85, 45],
        'pass': [0, 0, 1, 1, 1, 0, 1, 1, 1, 0]}
df = pd.DataFrame(data)
plt.figure(figsize = (8, 4))
sns.scatterplot(x = 'hours', y = 'score', hue = 'pass', style = 'pass', data = df, palette = 'coolwarm')
plt.suptitle("Pairplot for Pass / Fail")
plt.show()
sns.pairplot(df, hue = 'pass', palette = 'coolwarm', diag_kind = 'hist')
plt.suptitle("PairPlot for Pass / Fail")
plt.show()
plt.figure (figsize =(6, 4))
sns.boxplot(x = 'pass', y = 'score', data = df, palette = 'viridis')
plt.title('Box Plot')
plt.xlabel('Pass (1) / Fail (0)')
plt.ylabel('Score')
plt.show()
# Out:
# /tmp/ipython-input-1737452533.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'pass', y = 'score', data = df, palette = 'viridis')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
data={'hours':[2,4,6,8,10,3,5,7,9,1],'score':[50,60,70,80,90,55,65,75,85,45],
      'pass':[0,0,1,1,1,0,1,1,1,0]}
df=pd.DataFrame(data)
plt.figure(figsize=(8,4))
sns.scatterplot(x='hours',y='score',hue='pass',style='pass',data=df,palette='coolwarm')
plt.suptitle('Pairplot for pass/fail',y=1.02)
plt.show()
sns.pairplot(df,hue='pass',palette='cool',diag_kind='hist')
plt.suptitle("Pairplot for pass/fail")
plt.show()
plt.figure(figsize=(6,4))
sns.boxplot(x='pass',y='score',data=df,palette='viridis')
plt.title('Box plot')
plt.xlabel('pass(1) / fail(0)')
plt.show()
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='hours',hue='pass',multiple='stack',palette='viridis')
plt.title('Hist plot')
plt.show()
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='cool',vmin=-1,vmax=1)
plt.show()
# Out:
# /tmp/ipython-input-3202476177.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='pass',y='score',data=df,palette='viridis')

# %%
import  pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,classification_report
import matplotlib.colors as mcolors
sns.set_style('whitegrid')
data={'hours':[2,4,6,8,10,3,5,7,9,1],'score':[50,60,70,80,90,55,65,75,85,45],
      'pass':[0,0,1,1,1,0,1,1,1,0]}
df=pd.DataFrame(data)
x=df[['hours','score']]
y=df['pass']
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy::{accuracy:.2f}")
print('\n Classification Report : ')
print(classification_report(y_test,y_pred))
new_student=np.array([[5,70]])
prediction=model.predict(new_student)
print("\n Prediction of new student(hrs=5,score=70):{'pass' if prediction[0]==1 else 'Fail'}")
plt.figure(figsize=(10,6))
sns.scatterplot(x='hours',y='score',hue='pass',style='pass',size='pass',data=df,palette='hot')
x_min,x_max=x['hours'].min()-1,x['hours'].max()+1
y_min,y_max=x['score'].min()-5,x['score'].max()+5
xx,yy=np.meshgrid(np.arange(x_min,x_max,0.1),np.arange(y_min,y_max,0.1))
z=model.predict(np.c_[xx.ravel(),yy.ravel()])
z=z.reshape(xx.shape)
z = z.astype(float) # Convert z to float
plt.contour(xx,yy,z,alpha=0.3,cmap='plasma')
plt.legend()
plt.show()
cm=confusion_matrix(y_test,y_pred)
uc=['red','blue','green','orange']
custom_cmap=mcolors.ListedColormap(uc)
sns.heatmap(cm,cmap=custom_cmap,cbar=False)
plt.show()
# Out:
# Accuracy::0.67
#
#  Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3
#
#
#  Prediction of new student(hrs=5,score=70):{'pass' if prediction[0]==1 else 'Fail'}
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
